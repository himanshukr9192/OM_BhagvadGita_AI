# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import warnings
warnings.filterwarnings('ignore')
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Embedding
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import load_model
from flask import Flask, render_template, request

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/bhagavad-gita-versewise/bhagavad_gita.csv

# %% [markdown]
# # ****DATA Loading

# %%
data = pd.read_csv('/kaggle/input/bhagavad-gita-versewise/bhagavad_gita.csv')
data.head()
# Out:
#    Unnamed: 0          verse_number  \
# 0           0    Chapter 1, Verse 1
# 1           1    Chapter 1, Verse 2
# 2           2    Chapter 1, Verse 3
# 3           3  Chapter 1, Verse 4-6
# 4           4  Chapter 1, Verse 4-6
#
#                                    verse_in_sanskrit  \
# 0  धृतराष्ट्र उवाच |धर्मक्षेत्रे कुरुक्षेत्रे समव...
# 1  सञ्जय उवाच ।दृष्ट्वा तु पाण्डवानीकं व्यूढं दुर...
# 2  पश्यैतां पाण्डुपुत्राणामाचार्य महतीं चमूम् ।व्...
# 3  अत्र शूरा महेष्वासा भीमार्जुनसमा युधि  युयुधान...
# 4  अत्र शूरा महेष्वासा भीमार्जुनसमा युधि  युयुधान...
#
#                       sanskrit_verse_transliteration  \
# 0  dhṛitarāśhtra uvācha dharma-kṣhetre kuru-kṣhet...
# 1  sañjaya uvācha dṛiṣhṭvā tu pāṇḍavānīkaṁ vyūḍha...
# 2  paśhyaitāṁ pāṇḍu-putrāṇām āchārya mahatīṁ cham...
# 3  atra śhūrā maheṣhvāsā bhīmārjuna-samā yudhiyuy...
# 4  atra śhūrā maheṣhvāsā bhīmārjuna-samā yudhiyuy...
#
#                               translation_in_english  \
# 0  Dhritarashtra said: O Sanjay, after gathering ...
# 1  Sanjay said: On observing the Pandava army sta...
# 2  Duryodhan said: Respected teacher!Behold the m...
# 3  Behold in their ranks are many powerful warrio...
# 4  Behold in their ranks are many powerful warrio...
#
#                                   meaning_in_english  \
# 0  The two armies had gathered on the battlefield...
# 1  Sanjay understood Dhritarashtra’s concern, who...
# 2  Duryodhana asked Dronacharya to look at the sk...
# 3  Due to his anxiety, the Pandava army seemed mu...
# 4  Due to his anxiety, the Pandava army seemed mu...
#
#                                 translation_in_hindi  \
# 0  धृतराष्ट्र ने कहाः हे संजय! कुरुक्षेत्र की पवि...
# 1  संजय ने कहाः हे राजन्! पाण्डवों की सेना की व्य...
# 2  दुर्योधन ने कहाः पूज्य आचार्य! पाण्डु पुत्रों ...
# 3  यहाँ इस सेना में भीम और अर्जुन के समान बलशाली ...
# 4  यहाँ इस सेना में भीम और अर्जुन के समान बलशाली ...
#
#                                     meaning_in_hindi
# 0  राजा धृतराष्ट्र जन्म से नेत्रहीन होने के अतिरि...
# 1  धृतराष्ट्र इस बात की पुष्टि करना चाहता था कि क...
# 2  दुर्योधन एक कुशल कूटनीतिज्ञ के रूप में अपने से...
# 3  अपने सम्मख संकट को मंडराते देखकर दुर्योधन को प...
# 4  अपने सम्मख संकट को मंडराते देखकर दुर्योधन को प...

# %% [markdown]
# # ****DATA Insight

# %%
data.shape
# Out:
# (701, 8)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 701 entries, 0 to 700
# Data columns (total 8 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Unnamed: 0                      701 non-null    int64
#  1   verse_number                    701 non-null    object
#  2   verse_in_sanskrit               701 non-null    object
#  3   sanskrit_verse_transliteration  701 non-null    object
#  4   translation_in_english          701 non-null    object
#  5   meaning_in_english              701 non-null    object
#  6   translation_in_hindi            701 non-null    object
#  7   meaning_in_hindi                700 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 43.9+ KB

# %%
data.isnull().sum()
# Out:
# Unnamed: 0                        0
# verse_number                      0
# verse_in_sanskrit                 0
# sanskrit_verse_transliteration    0
# translation_in_english            0
# meaning_in_english                0
# translation_in_hindi              0
# meaning_in_hindi                  1
# dtype: int64

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'verse_number', 'verse_in_sanskrit',
#        'sanskrit_verse_transliteration', 'translation_in_english',
#        'meaning_in_english', 'translation_in_hindi', 'meaning_in_hindi'],
#       dtype='object')

# %% [markdown]
# # DATA Preprocessing

# %%
if 'Unnamed: 0' in data.columns:
    data.drop('Unnamed: 0', axis=1, inplace=True)

data.shape
# Out:
# (701, 7)

# %% [markdown]
# # ****Tokenization

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(data)
sequences = tokenizer.texts_to_sequences(data)

# %% [markdown]
# #  ****Splitting

# %%
sequences_padded = pad_sequences(sequences)
sequences = np.array(sequences_padded)

# %%
X = sequences[:, :-1]
y = sequences[:, -1]
vocab_size = len(tokenizer.word_index) + 1

# %% [markdown]
# # ****ONE-Hot Encoding

# %%
from keras.utils import to_categorical

y = to_categorical(y, num_classes=vocab_size)

# %% [markdown]
# # ****Defining the model

# %%
model = Sequential()
model.add(Embedding(vocab_size, 50, input_length=X.shape[1]))
model.add(LSTM(100, return_sequences=True))
model.add(LSTM(100))
model.add(Dense(100, activation='relu'))
model.add(Dense(vocab_size, activation='softmax'))

# %% [markdown]
# # ****Compiling and Training the model

# %%
# Compile and train the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X, y, epochs=100, verbose=2)

# Use the model to generate text
def generate_text(seed_text, model, tokenizer, max_sequence_len):
    input_text = seed_text
    for _ in range(max_sequence_len):
        token_list = tokenizer.texts_to_sequences([input_text])[0]
        token_list = pad_sequences([token_list], maxlen=max_sequence_len-1, padding='pre')
        predicted = model.predict_classes(token_list, verbose=0)
        output_word = ""
        for word, index in tokenizer.word_index.items():
            if index == predicted:
                output_word = word
                break
        input_text += " " + output_word
    return input_text
# Out:
# Epoch 1/100
# 1/1 - 4s - loss: 2.3026 - accuracy: 0.1429 - 4s/epoch - 4s/step
# Epoch 2/100
# 1/1 - 0s - loss: 2.2978 - accuracy: 0.4286 - 10ms/epoch - 10ms/step
# Epoch 3/100
# 1/1 - 0s - loss: 2.2931 - accuracy: 0.2857 - 10ms/epoch - 10ms/step
# Epoch 4/100
# 1/1 - 0s - loss: 2.2880 - accuracy: 0.2857 - 11ms/epoch - 11ms/step
# Epoch 5/100
# 1/1 - 0s - loss: 2.2823 - accuracy: 0.2857 - 11ms/epoch - 11ms/step
# Epoch 6/100
# 1/1 - 0s - loss: 2.2762 - accuracy: 0.2857 - 11ms/epoch - 11ms/step
# Epoch 7/100
# 1/1 - 0s - loss: 2.2695 - accuracy: 0.2857 - 9ms/epoch - 9ms/step
# Epoch 8/100
# 1/1 - 0s - loss: 2.2621 - accuracy: 0.2857 - 12ms/epoch - 12ms/step
# Epoch 9/100
# 1/1 - 0s - loss: 2.2539 - accuracy: 0.2857 - 11ms/epoch - 11ms/step
# Epoch 10/100
# 1/1 - 0s - loss: 2.2450 - accuracy: 0.2857 - 11ms/epoch - 11ms/step
# Epoch 11/100
# 1/1 - 0s - loss: 2.2350 - accuracy: 0.2857 - 11ms/epoch - 11ms/step
# Epoch 12/100
# 1/1 - 0s - loss: 2.2237 - accuracy: 0.2857 - 10ms/epoch - 10ms/step
# Epoch 13/100
# 1/1 - 0s - loss: 2.2111 - accuracy: 0.2857 - 11ms/epoch - 11ms/step
# Epoch 14/100
# 1/1 - 0s - loss: 2.1971 - accuracy: 0.2857 - 10ms/epoch - 10ms/step
# Epoch 15/100
# 1/1 - 0s - loss: 2.1813 - accuracy: 0.2857 - 9ms/epoch - 9ms/step
# Epoch 16/100
# 1/1 - 0s - loss: 2.1636 - accuracy: 0.2857 - 10ms/epoch - 10ms/step
# Epoch 17/100
# 1/1 - 0s - loss: 2.1436 - accuracy: 0.2857 - 10ms/epoch - 10ms/step
# Epoch 18/100
# 1/1 - 0s - loss: 2.1211 - accuracy: 0.2857 - 11ms/epoch - 11ms/step
# Epoch 19/100
# 1/1 - 0s - loss: 2.0957 - accuracy: 0.2857 - 10ms/epoch - 10ms/step
# Epoch 20/100
# 1/1 - 0s - loss: 2.0673 - accuracy: 0.2857 - 8ms/epoch - 8ms/step
# Epoch 21/100
# 1/1 - 0s - loss: 2.0353 - accuracy: 0.2857 - 9ms/epoch - 9ms/step
# Epoch 22/100
# 1/1 - 0s - loss: 1.9995 - accuracy: 0.2857 - 10ms/epoch - 10ms/step
# Epoch 23/100
# 1/1 - 0s - loss: 1.9595 - accuracy: 0.2857 - 10ms/epoch - 10ms/step
# Epoch 24/100
# 1/1 - 0s - loss: 1.9152 - accuracy: 0.2857 - 10ms/epoch - 10ms/step
# Epoch 25/100
# 1/1 - 0s - loss: 1.8664 - accuracy: 0.2857 - 10ms/epoch - 10ms/step
# Epoch 26/100
# 1/1 - 0s - loss: 1.8134 - accuracy: 0.2857 - 11ms/epoch - 11ms/step
# Epoch 27/100
# 1/1 - 0s - loss: 1.7566 - accuracy: 0.2857 - 13ms/epoch - 13ms/step
# Epoch 28/100
# 1/1 - 0s - loss: 1.6972 - accuracy: 0.2857 - 11ms/epoch - 11ms/step
# Epoch 29/100
# 1/1 - 0s - loss: 1.6367 - accuracy: 0.2857 - 11ms/epoch - 11ms/step
# Epoch 30/100
# 1/1 - 0s - loss: 1.5776 - accuracy: 0.2857 - 10ms/epoch - 10ms/step
# Epoch 31/100
# 1/1 - 0s - loss: 1.5224 - accuracy: 0.2857 - 12ms/epoch - 12ms/step
# Epoch 32/100
# 1/1 - 0s - loss: 1.4735 - accuracy: 0.2857 - 11ms/epoch - 11ms/step
# Epoch 33/100
# 1/1 - 0s - loss: 1.4322 - accuracy: 0.2857 - 11ms/epoch - 11ms/step
# Epoch 34/100
# 1/1 - 0s - loss: 1.3974 - accuracy: 0.2857 - 10ms/epoch - 10ms/step
# Epoch 35/100
# 1/1 - 0s - loss: 1.3661 - accuracy: 0.2857 - 11ms/epoch - 11ms/step
# Epoch 36/100
# 1/1 - 0s - loss: 1.3357 - accuracy: 0.2857 - 13ms/epoch - 13ms/step
# Epoch 37/100
# 1/1 - 0s - loss: 1.3053 - accuracy: 0.2857 - 9ms/epoch - 9ms/step
# Epoch 38/100
# 1/1 - 0s - loss: 1.2754 - accuracy: 0.2857 - 10ms/epoch - 10ms/step
# Epoch 39/100
# 1/1 - 0s - loss: 1.2488 - accuracy: 0.4286 - 10ms/epoch - 10ms/step
# Epoch 40/100
# 1/1 - 0s - loss: 1.2279 - accuracy: 0.4286 - 10ms/epoch - 10ms/step
# Epoch 41/100
# 1/1 - 0s - loss: 1.2117 - accuracy: 0.4286 - 10ms/epoch - 10ms/step
# Epoch 42/100
# 1/1 - 0s - loss: 1.1973 - accuracy: 0.4286 - 9ms/epoch - 9ms/step
# Epoch 43/100
# 1/1 - 0s - loss: 1.1807 - accuracy: 0.4286 - 10ms/epoch - 10ms/step
# Epoch 44/100
# 1/1 - 0s - loss: 1.1590 - accuracy: 0.4286 - 10ms/epoch - 10ms/step
# Epoch 45/100
# 1/1 - 0s - loss: 1.1349 - accuracy: 0.4286 - 10ms/epoch - 10ms/step
# Epoch 46/100
# 1/1 - 0s - loss: 1.1124 - accuracy: 0.4286 - 12ms/epoch - 12ms/step
# Epoch 47/100
# 1/1 - 0s - loss: 1.0933 - accuracy: 0.4286 - 11ms/epoch - 11ms/step
# Epoch 48/100
# 1/1 - 0s - loss: 1.0752 - accuracy: 0.4286 - 11ms/epoch - 11ms/step
# Epoch 49/100
# 1/1 - 0s - loss: 1.0529 - accuracy: 0.4286 - 12ms/epoch - 12ms/step
# Epoch 50/100
# 1/1 - 0s - loss: 1.0253 - accuracy: 0.4286 - 9ms/epoch - 9ms/step
# Epoch 51/100
# 1/1 - 0s - loss: 0.9955 - accuracy: 0.4286 - 11ms/epoch - 11ms/step
# Epoch 52/100
# 1/1 - 0s - loss: 0.9677 - accuracy: 0.4286 - 11ms/epoch - 11ms/step
# Epoch 53/100
# 1/1 - 0s - loss: 0.9441 - accuracy: 0.4286 - 11ms/epoch - 11ms/step
# Epoch 54/100
# 1/1 - 0s - loss: 0.9226 - accuracy: 0.4286 - 9ms/epoch - 9ms/step
# Epoch 55/100
# 1/1 - 0s - loss: 0.8994 - accuracy: 0.4286 - 9ms/epoch - 9ms/step
# Epoch 56/100
# 1/1 - 0s - loss: 0.8744 - accuracy: 0.5714 - 11ms/epoch - 11ms/step
# Epoch 57/100
# 1/1 - 0s - loss: 0.8496 - accuracy: 0.5714 - 10ms/epoch - 10ms/step
# Epoch 58/100
# 1/1 - 0s - loss: 0.8272 - accuracy: 0.5714 - 10ms/epoch - 10ms/step
# Epoch 59/100
# 1/1 - 0s - loss: 0.8071 - accuracy: 0.5714 - 12ms/epoch - 12ms/step
# Epoch 60/100
# 1/1 - 0s - loss: 0.7864 - accuracy: 0.5714 - 11ms/epoch - 11ms/step
# Epoch 61/100
# 1/1 - 0s - loss: 0.7643 - accuracy: 0.5714 - 13ms/epoch - 13ms/step
# Epoch 62/100
# 1/1 - 0s - loss: 0.7417 - accuracy: 0.5714 - 10ms/epoch - 10ms/step
# Epoch 63/100
# 1/1 - 0s - loss: 0.7208 - accuracy: 0.5714 - 11ms/epoch - 11ms/step
# Epoch 64/100
# 1/1 - 0s - loss: 0.7016 - accuracy: 0.5714 - 9ms/epoch - 9ms/step
# Epoch 65/100
# 1/1 - 0s - loss: 0.6831 - accuracy: 0.5714 - 11ms/epoch - 11ms/step
# Epoch 66/100
# 1/1 - 0s - loss: 0.6642 - accuracy: 0.7143 - 11ms/epoch - 11ms/step
# Epoch 67/100
# 1/1 - 0s - loss: 0.6462 - accuracy: 0.7143 - 10ms/epoch - 10ms/step
# Epoch 68/100
# 1/1 - 0s - loss: 0.6302 - accuracy: 0.7143 - 11ms/epoch - 11ms/step
# Epoch 69/100
# 1/1 - 0s - loss: 0.6152 - accuracy: 0.7143 - 11ms/epoch - 11ms/step
# Epoch 70/100
# 1/1 - 0s - loss: 0.6001 - accuracy: 0.7143 - 10ms/epoch - 10ms/step
# Epoch 71/100
# 1/1 - 0s - loss: 0.5847 - accuracy: 0.7143 - 10ms/epoch - 10ms/step
# Epoch 72/100
# 1/1 - 0s - loss: 0.5700 - accuracy: 0.7143 - 12ms/epoch - 12ms/step
# Epoch 73/100
# 1/1 - 0s - loss: 0.5565 - accuracy: 0.7143 - 11ms/epoch - 11ms/step
# Epoch 74/100
# 1/1 - 0s - loss: 0.5432 - accuracy: 0.7143 - 9ms/epoch - 9ms/step
# Epoch 75/100
# 1/1 - 0s - loss: 0.5296 - accuracy: 0.7143 - 12ms/epoch - 12ms/step
# Epoch 76/100
# 1/1 - 0s - loss: 0.5168 - accuracy: 0.7143 - 9ms/epoch - 9ms/step
# Epoch 77/100
# 1/1 - 0s - loss: 0.5046 - accuracy: 0.7143 - 8ms/epoch - 8ms/step
# Epoch 78/100
# 1/1 - 0s - loss: 0.4931 - accuracy: 0.7143 - 9ms/epoch - 9ms/step
# Epoch 79/100
# 1/1 - 0s - loss: 0.4819 - accuracy: 0.7143 - 10ms/epoch - 10ms/step
# Epoch 80/100
# 1/1 - 0s - loss: 0.4711 - accuracy: 0.7143 - 9ms/epoch - 9ms/step
# Epoch 81/100
# 1/1 - 0s - loss: 0.4610 - accuracy: 0.7143 - 9ms/epoch - 9ms/step
# Epoch 82/100
# 1/1 - 0s - loss: 0.4515 - accuracy: 0.7143 - 11ms/epoch - 11ms/step
# Epoch 83/100
# 1/1 - 0s - loss: 0.4428 - accuracy: 0.7143 - 9ms/epoch - 9ms/step
# Epoch 84/100
# 1/1 - 0s - loss: 0.4352 - accuracy: 0.7143 - 9ms/epoch - 9ms/step
# Epoch 85/100
# 1/1 - 0s - loss: 0.4290 - accuracy: 0.7143 - 9ms/epoch - 9ms/step
# Epoch 86/100
# 1/1 - 0s - loss: 0.4235 - accuracy: 0.7143 - 10ms/epoch - 10ms/step
# Epoch 87/100
# 1/1 - 0s - loss: 0.4190 - accuracy: 0.7143 - 10ms/epoch - 10ms/step
# Epoch 88/100
# 1/1 - 0s - loss: 0.4156 - accuracy: 0.7143 - 11ms/epoch - 11ms/step
# Epoch 89/100
# 1/1 - 0s - loss: 0.4127 - accuracy: 0.7143 - 10ms/epoch - 10ms/step
# Epoch 90/100
# 1/1 - 0s - loss: 0.4103 - accuracy: 0.7143 - 13ms/epoch - 13ms/step
# Epoch 91/100
# 1/1 - 0s - loss: 0.4085 - accuracy: 0.7143 - 10ms/epoch - 10ms/step
# Epoch 92/100
# 1/1 - 0s - loss: 0.4070 - accuracy: 0.7143 - 12ms/epoch - 12ms/step
# Epoch 93/100
# 1/1 - 0s - loss: 0.4057 - accuracy: 0.7143 - 10ms/epoch - 10ms/step
# Epoch 94/100
# 1/1 - 0s - loss: 0.4047 - accuracy: 0.7143 - 12ms/epoch - 12ms/step
# Epoch 95/100
# 1/1 - 0s - loss: 0.4038 - accuracy: 0.7143 - 10ms/epoch - 10ms/step
# Epoch 96/100
# 1/1 - 0s - loss: 0.4031 - accuracy: 0.7143 - 10ms/epoch - 10ms/step
# Epoch 97/100
# 1/1 - 0s - loss: 0.4024 - accuracy: 0.7143 - 12ms/epoch - 12ms/step
# Epoch 98/100
# 1/1 - 0s - loss: 0.4019 - accuracy: 0.7143 - 11ms/epoch - 11ms/step
# Epoch 99/100
# 1/1 - 0s - loss: 0.4014 - accuracy: 0.7143 - 12ms/epoch - 12ms/step
# Epoch 100/100
# 1/1 - 0s - loss: 0.4010 - accuracy: 0.7143 - 13ms/epoch - 13ms/step

# %% [markdown]
# # Saving The Model

# %%
model.save('Bhagvad_gita_chatbot_model.h5')

# %% [markdown]
# # Loading The Model

# %%
model = load_model('Bhagvad_gita_chatbot_model.h5')

# %% [markdown]
# # ****Creating a Function to Handle User Input

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(data)
sequences = tokenizer.texts_to_sequences(data)

# %%
def handle_message(message):
    # Preprocess the message
    token_list = tokenizer.texts_to_sequences([message])[0]
    token_list = pad_sequences([token_list], maxlen=max_sequence_len-1, padding='pre')

    # Get the model's response
    predicted = model.predict_classes(token_list, verbose=0)

    # Postprocess the response
    output_word = ""
    for word, index in tokenizer.word_index.items():
        if index == predicted:
            output_word = word
            break

    return output_word

# %% [markdown]
# # ****Creating a User Interface And Connecting the UI to the Model

# %%
model = load_model('Bhagvad_gita_chatbot_model.h5')

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(data)
sequences = tokenizer.texts_to_sequences(data)

# %%
# !pip install --upgrade gradio
# !pip install --upgrade pydantic
# Out:
# Requirement already satisfied: gradio in /opt/conda/lib/python3.10/site-packages (4.12.0)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in /opt/conda/lib/python3.10/site-packages (from gradio) (23.2.1)
# Requirement already satisfied: altair<6.0,>=4.2.0 in /opt/conda/lib/python3.10/site-packages (from gradio) (5.2.0)
# Requirement already satisfied: fastapi in /opt/conda/lib/python3.10/site-packages (from gradio) (0.101.1)
# Requirement already satisfied: ffmpy in /opt/conda/lib/python3.10/site-packages (from gradio) (0.3.1)
# Requirement already satisfied: gradio-client==0.8.0 in /opt/conda/lib/python3.10/site-packages (from gradio) (0.8.0)
# Requirement already satisfied: httpx in /opt/conda/lib/python3.10/site-packages (from gradio) (0.26.0)
# Requirement already satisfied: huggingface-hub>=0.19.3 in /opt/conda/lib/python3.10/site-packages (from gradio) (0.19.4)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in /opt/conda/lib/python3.10/site-packages (from gradio) (5.13.0)
# Requirement already satisfied: jinja2<4.0 in /opt/conda/lib/python3.10/site-packages (from gradio) (3.1.2)
# Requirement already satisfied: markupsafe~=2.0 in /opt/conda/lib/python3.10/site-packages (from gradio) (2.1.3)
# Requirement already satisfied: matplotlib~=3.0 in /opt/conda/lib/python3.10/site-packages (from gradio) (3.5.3)
# Requirement already satisfied: numpy~=1.0 in /opt/conda/lib/python3.10/site-packages (from gradio) (1.23.5)
# Requirement already satisfied: orjson~=3.0 in /opt/conda/lib/python3.10/site-packages (from gradio) (3.9.5)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from gradio) (20.9)
# Requirement already satisfied: pandas<3.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from gradio) (2.0.3)
# Requirement already satisfied: pillow<11.0,>=8.0 in /opt/conda/lib/python3.10/site-packages (from gradio) (10.1.0)
# Requirement already satisfied: pydantic>=2.0 in /opt/conda/lib/python3.10/site-packages (from gradio) (2.5.3)
# Requirement already satisfied: pydub in /opt/conda/lib/python3.10/site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart in /opt/conda/lib/python3.10/site-packages (from gradio) (0.0.6)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /opt/conda/lib/python3.10/site-packages (from gradio) (6.0.1)
# Requirement already satisfied: semantic-version~=2.0 in /opt/conda/lib/python3.10/site-packages (from gradio) (2.10.0)
# Requirement already satisfied: tomlkit==0.12.0 in /opt/conda/lib/python3.10/site-packages (from gradio) (0.12.0)
# Requirement already satisfied: typer<1.0,>=0.9 in /opt/conda/lib/python3.10/site-packages (from typer[all]<1.0,>=0.9->gradio) (0.9.0)
# Requirement already satisfied: typing-extensions~=4.0 in /opt/conda/lib/python3.10/site-packages (from gradio) (4.7.1)
# Requirement already satisfied: uvicorn>=0.14.0 in /opt/conda/lib/python3.10/site-packages (from gradio) (0.23.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from gradio-client==0.8.0->gradio) (2023.12.2)
# Requirement already satisfied: websockets<12.0,>=10.0 in /opt/conda/lib/python3.10/site-packages (from gradio-client==0.8.0->gradio) (10.4)
# Requirement already satisfied: jsonschema>=3.0 in /opt/conda/lib/python3.10/site-packages (from altair<6.0,>=4.2.0->gradio) (4.17.3)
# Requirement already satisfied: toolz in /opt/conda/lib/python3.10/site-packages (from altair<6.0,>=4.2.0->gradio) (0.12.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.19.3->gradio) (3.12.2)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.19.3->gradio) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.19.3->gradio) (4.66.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib~=3.0->gradio) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib~=3.0->gradio) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib~=3.0->gradio) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib~=3.0->gradio) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib~=3.0->gradio) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas<3.0,>=1.0->gradio) (2022.7.1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas<3.0,>=1.0->gradio) (2023.3)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from pydantic>=2.0->gradio) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in /opt/conda/lib/python3.10/site-packages (from pydantic>=2.0->gradio) (2.14.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /opt/conda/lib/python3.10/site-packages (from typer<1.0,>=0.9->typer[all]<1.0,>=0.9->gradio) (8.1.7)
# Requirement already satisfied: colorama<0.5.0,>=0.4.3 in /opt/conda/lib/python3.10/site-packages (from typer[all]<1.0,>=0.9->gradio) (0.4.6)
# Requirement already satisfied: shellingham<2.0.0,>=1.3.0 in /opt/conda/lib/python3.10/site-packages (from typer[all]<1.0,>=0.9->gradio) (1.5.4)
# Requirement already satisfied: rich<14.0.0,>=10.11.0 in /opt/conda/lib/python3.10/site-packages (from typer[all]<1.0,>=0.9->gradio) (13.5.2)
# Requirement already satisfied: h11>=0.8 in /opt/conda/lib/python3.10/site-packages (from uvicorn>=0.14.0->gradio) (0.14.0)
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in /opt/conda/lib/python3.10/site-packages (from fastapi->gradio) (0.27.0)
# Requirement already satisfied: anyio in /opt/conda/lib/python3.10/site-packages (from httpx->gradio) (3.7.1)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.10/site-packages (from httpx->gradio) (2023.11.17)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.10/site-packages (from httpx->gradio) (1.0.2)
# Requirement already satisfied: idna in /opt/conda/lib/python3.10/site-packages (from httpx->gradio) (3.4)
# Requirement already satisfied: sniffio in /opt/conda/lib/python3.10/site-packages (from httpx->gradio) (1.3.0)
# Requirement already satisfied: attrs>=17.4.0 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (0.20.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from rich<14.0.0,>=10.11.0->typer[all]<1.0,>=0.9->gradio) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from rich<14.0.0,>=10.11.0->typer[all]<1.0,>=0.9->gradio) (2.16.1)
# Requirement already satisfied: exceptiongroup in /opt/conda/lib/python3.10/site-packages (from anyio->httpx->gradio) (1.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.19.3->gradio) (3.2.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.19.3->gradio) (1.26.15)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=10.11.0->typer[all]<1.0,>=0.9->gradio) (0.1.2)
# WARNING: Error parsing requirements for babel: [Errno 2] No such file or directory: '/opt/conda/lib/python3.10/site-packages/Babel-2.12.1.dist-info/METADATA'
# Requirement already satisfied: pydantic in /opt/conda/lib/python3.10/site-packages (2.5.3)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from pydantic) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in /opt/conda/lib/python3.10/site-packages (from pydantic) (2.14.6)
# Requirement already satisfied: typing-extensions>=4.6.1 in /opt/conda/lib/python3.10/site-packages (from pydantic) (4.7.1)
# WARNING: Error parsing requirements for babel: [Errno 2] No such file or directory: '/opt/conda/lib/python3.10/site-packages/Babel-2.12.1.dist-info/METADATA'

# %%
#import gradio as gr

# %% [markdown]
# # can't be run on kaggle

# %%
#def respond(message):
    # Preprocess the message
#    token_list = tokenizer.texts_to_sequences([message])[0]
#    token_list = pad_sequences([token_list], maxlen=max_sequence_len-1, padding='pre')

    # Get the model's response
#    predicted = model.predict_classes(token_list, verbose=0)
 #   output_word = ""
 #   for word, index in tokenizer.word_index.items():
 #       if index == predicted:
  #          output_word = word
 #           break
  #  return output_word

#iface = gr.Interface(fn=respond, inputs="text", outputs="text")
#iface.launch()
